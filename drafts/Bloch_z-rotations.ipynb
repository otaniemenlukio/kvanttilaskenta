# %%
from qiskit import *
import math

qreg = QuantumRegister(1)
creg = ClassicalRegister(1)
circuit = QuantumCircuit(qreg, creg)
circuit.h(qreg[0])
circuit.s(qreg[0])
#circuit.t(qreg[0])
circuit.h(qreg[0])
circuit.draw(output='mpl')

# %%
#circuit.measure(qreg[0],creg[0])

simulator = Aer.get_backend('statevector_simulator')

# Suoritetaan
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)

# Tulostetaan saatu tila ket-notaation kera
for i, c in enumerate(statevector):
    print(c, f"|{i:01b}>")

visualization.plot_bloch_multivector(statevector, title="tilavektori")
# Out:
# (0.1464466094067265+0.35355339059327373j) |0>
# (0.8535533905932737-0.3535533905932738j) |1>

# %%
circuit.h(qreg[0])

# %%
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)

# Tulostetaan saatu tila ket-notaation kera
for i, c in enumerate(statevector):
    print(c, f"|{i:01b}>")

visualization.plot_bloch_multivector(statevector, title="tilavektori")
# Out:
# (1-6.123233995736765e-17j) |0>
# 6.123233995736766e-17j |1>
